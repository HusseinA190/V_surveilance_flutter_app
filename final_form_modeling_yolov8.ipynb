# %% [markdown]
# <a href="https://colab.research.google.com/github/HusseinA190/V_surveilance_flutter_app/blob/main/final_form_modeling_yolov8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # some imports and initializing libraries

# %%
import torch
import matplotlib.pyplot as plt
import cv2 as cv
torch.cuda.empty_cache()

# %%
# installing ultralytics for yolo models
# !pip install -q ultralytics
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 654.0/654.0 kB 10.4 MB/s eta 0:00:00

# %%
# importing yolo model
from ultralytics import YOLO

# %% [markdown]
# ## extracting and zipping file and data

# %%
# !pip install unrar
# Out:
# Requirement already satisfied: unrar in /usr/local/lib/python3.10/dist-packages (0.4)

# %%
# unrar .rar files using unrar method
# !unrar x '/content/drive/MyDrive/Violence_data/sub_data.rar'

# %%
# extract data using unzip method
# !unzip -q /content/drive/MyDrive/Violence_data/FINAL_VIO_FILTER_SH.zip

# %%
# zipping data using zip method
# !zip "/content/drive/MyDrive/Violence_data/vio_no_bg.zip" -r "/content/VIO_2"

# %%
# !unzip -q "/content/drive/MyDrive/Violence_data/vio_no_bg.zip"

# %% [markdown]
# # Medical test 1

# %% [markdown]
# ## Medical Test 1

# %%
# loading yolo model weights
model_medical_test_1 = YOLO('yolov8s.pt')

# %%
#  initializing model params for training
results_medicaltest_1 = model_medical_test_1.train(data = "/content/sub_data/data.yaml" , epochs = 25 , imgsz = 416 , project = '/content/drive/MyDrive/medical_test_1')
# Out:
# Ultralytics YOLOv8.0.222 🚀 Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# engine/trainer: task=detect, mode=train, model=yolov8s.pt, data=/content/sub_data/data.yaml, epochs=25, patience=50, batch=16, imgsz=416, save=True, save_period=-1, cache=False, device=None, workers=8, project=/content/drive/MyDrive/medical_test_1, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0, cfg=None, tracker=botsort.yaml, save_dir=/content/drive/MyDrive/medical_test_1/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|██████████| 755k/755k [00:00<00:00, 14.9MB/s]
# Overriding model.yaml nc=80 with nc=11
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2120305  ultralytics.nn.modules.head.Detect           [11, [128, 256, 512]]
# Model summary: 225 layers, 11139857 parameters, 11139841 gradients, 28.7 GFLOPs
#
# Transferred 64/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir /content/drive/MyDrive/medical_test_1/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 117MB/s]
# AMP: checks passed ✅
# train: Scanning /content/sub_data/train/labels... 839 images, 0 backgrounds, 0 corrupt: 100%|██████████| 839/839 [00:00<00:00, 1593.66it/s]
# train: New cache created: /content/sub_data/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/sub_data/valid/labels... 813 images, 0 backgrounds, 0 corrupt: 100%|██████████| 813/813 [00:01<00:00, 674.35it/s]
# val: New cache created: /content/sub_data/valid/labels.cache
# Plotting labels to /content/drive/MyDrive/medical_test_1/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000667, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 416 train, 416 val
# Using 2 dataloader workers
# Logging results to /content/drive/MyDrive/medical_test_1/train
# Starting training for 25 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/25      1.91G      1.343      3.822      1.425         15        416: 100%|██████████| 53/53 [00:20<00:00,  2.61it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:11<00:00,  2.21it/s]
#                    all        813        813      0.527      0.399      0.344      0.253
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/25      1.86G     0.9347      1.913       1.13         15        416: 100%|██████████| 53/53 [00:16<00:00,  3.29it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:08<00:00,  2.95it/s]
#                    all        813        813      0.768      0.393       0.45      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/25         2G     0.8232      1.365      1.052         15        416: 100%|██████████| 53/53 [00:12<00:00,  4.17it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:10<00:00,  2.49it/s]
#                    all        813        813      0.773      0.447      0.507      0.405
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/25         2G     0.7794      1.129      1.032         16        416: 100%|██████████| 53/53 [00:14<00:00,  3.64it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:06<00:00,  3.74it/s]
#                    all        813        813      0.817      0.461       0.48      0.401
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/25      1.86G     0.7428      1.043      1.007         14        416: 100%|██████████| 53/53 [00:14<00:00,  3.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:08<00:00,  3.12it/s]
#                    all        813        813      0.789      0.515      0.531      0.428
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/25      1.85G     0.7208     0.8927     0.9943         11        416: 100%|██████████| 53/53 [00:14<00:00,  3.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:07<00:00,  3.35it/s]
#                    all        813        813      0.825      0.494      0.514      0.423
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/25         2G     0.7221     0.8501      1.009         13        416: 100%|██████████| 53/53 [00:14<00:00,  3.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:07<00:00,  3.44it/s]
#                    all        813        813      0.833      0.515      0.497      0.414
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/25         2G     0.6839     0.7692     0.9792         15        416: 100%|██████████| 53/53 [00:12<00:00,  4.11it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:09<00:00,  2
parameters, 0 gradients, 28.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 26/26 [00:11<00:00,  2.21it/s]
#                    all        813        813      0.763      0.531      0.613      0.517
#                      0        813         63      0.958          1      0.994      0.868
#                      1        813         98          1      0.392      0.823      0.586
#                     10        813         21      0.823          1      0.995      0.948
#                      2        813         74          1      0.296       0.66      0.575
#                      3        813         69      0.306      0.798       0.46       0.39
#                      4        813        104      0.635       0.99      0.841      0.635
#                      5        813         75      0.735      0.213      0.487      0.374
#                      6        813         78          0          0          0          0
#                      7        813         77      0.986      0.273      0.504      0.456
#                      8        813         82      0.947      0.877      0.981      0.859
#                      9        813         72          1          0          0          0
# Speed: 0.1ms preprocess, 2.3ms inference, 0.0ms loss, 1.9ms postprocess per image
# Results saved to /content/drive/MyDrive/medical_test_1/train

# %% [markdown]
# ## test medical 1

# %%
# loading trained custom model weights
model_medical= YOLO('/content/drive/MyDrive/medical_test_1/train/weights/best.pt')

# %%
# predict on imgs using trained weights
result_img_medical = model_medical('/content/pills_val12_jpg.rf.218b31fbf3996698f815463b56561d7d.jpg')
# Out:
# image 1/1 /content/pills_val12_jpg.rf.218b31fbf3996698f815463b56561d7d.jpg: 416x416 1 0, 73.1ms
# Speed: 16.1ms preprocess, 73.1ms inference, 8.0ms postprocess per image at shape (1, 3, 416, 416)

# %%
# visualizing predicted imgs
img = result_img_medical[0].plot()
# img = plt.imshow(img,cmap='gray')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %% [markdown]
# # experiemnets on last project of violence - fire - smoke - weapons with methods of predcits and others to look on it

# %% [markdown]
# ## train from pre-trained weights

# %%
model = YOLO("/content/drive/MyDrive/Violence_data/salwa_with_aug/train/weights/best.pt")

# %%
results = model.train(data = '/content/drive/MyDrive/Violence_data/vio_filter.yaml' , project = "/content/drive/MyDrive/Violence_data/final_filter_vio_sh" ,
                      val = False ,
                      epochs = 100 ,
                      augment = True ,
                      cos_lr = True ,
                      agnostic_nms = True ,
                      batch = 64 ,
                      imgsz = 416 ,
                      optimizer = "Adamax",
                      lr0 = 0.001,
                      hsv_h = 0.8,
                      hsv_s = 0.8,
                      hsv_v = 0.8,
                      degrees =  1.0,
                      translate = 1.0,
                      scale = 0.9,
                      shear = 0.8,
                      flipud = 1.0,
                      fliplr = 1.0,
                      mosaic = 1.0,
                      mixup = 1.0,
                      copy_paste = 0.9)
# Out:
# Ultralytics YOLOv8.0.115 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# yolo/engine/trainer: task=detect, mode=train, model=yolov8s.pt, data=/content/drive/MyDrive/Violence_data/vio_filter.yaml, epochs=100, patience=50, batch=64, imgsz=416, save=True, save_period=-1, cache=False, device=None, workers=8, project=/content/drive/MyDrive/Violence_data/final_filter_vio_sh, name=None, exist_ok=False, pretrained=False, optimizer=Adamax, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=True, close_mosaic=0, resume=False, amp=True, fraction=1.0, profile=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=False, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_width=None, visualize=False, augment=True, agnostic_nms=True, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.001, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.8, hsv_s=0.8, hsv_v=0.8, degrees=1.0, translate=1.0, scale=0.9, shear=0.8, perspective=0.0, flipud=1.0, fliplr=1.0, mosaic=1.0, mixup=1.0, copy_paste=0.9, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=/content/drive/MyDrive/Violence_data/final_filter_vio_sh/train2
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.head.Detect           [1, [128, 256, 512]]
# Model summary: 225 layers, 11135987 parameters, 11135971 gradients
#
# Transferred 355/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir /content/drive/MyDrive/Violence_data/final_filter_vio_sh/train2', view at http://localhost:6006/
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /content/content/VIO_2/train/labels.cache... 7047 images, 0 backgrounds, 0 corrupt: 100%|██████████| 7047/7047 [00:00<?, ?it/s]
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/content/VIO_2/valid/labels.cache... 112 images, 0 backgrounds, 0 corrupt: 100%|██████████| 112/112 [00:00<?, ?it/s]
# Plotting labels to /content/drive/MyDrive/Violence_data/final_filter_vio_sh/train2/labels.jpg...
# optimizer: Adamax(lr=0.001, momentum=0.937) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 416 train, 416 val
# Using 2 dataloader workers
# Logging results to /content/drive/MyDrive/Violence_data/final_filter_vio_sh/train2
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      8.13G      1.358       1.41      1.518         18        416: 100%|██████████| 111/111 [02:56<00:00,  1.59s/it]
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      7.19G       1.43      1.484      1.555         15        416: 100%|██████████| 111/111 [03:00<00:00,  1.63s/it]
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      7.19G      1.441      1.509      1.587         14        416: 100%|██████████| 111/111 [02:58<00:00,  1.61s/it]
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      7.19G      1.454      1.536      1.592         21        416: 100%|██████████| 111/111 [02:59<00:00,  1.62s/it]
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      7.19G      1.452      1.493      1.595         18        416: 100%|██████████| 111/111 [03:08<00:00,  1.70s/it]
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      7.19G      1.385      1.484      1.562        158        416:   4%|▎         | 4/111 [00:06<02:50,  1.59s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-184db9e8e40f> in <cell line: 1>()
# ----> 1 results = model.train(data = '/content/drive/MyDrive/Violence_data/vio_filter.yaml' , project = "/content/drive/MyDrive/Violence_data/final_filter_vio_sh" ,
#       2                       val = False ,
#       3                       epochs = 100 ,
#       4                       augment = True ,
#       5                       cos_lr = True ,
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/model.py in train(self, **kwargs)
#     369             self.model = self.trainer.model
#     370         self.trainer.hub_session = self.session  # attach optional HUB session
# --> 371         self.trainer.train()
#     372         # Update model and cfg after training
#     373         if RANK in (-1, 0):
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/trainer.py in train(self)
#     190                 ddp_cleanup(self, str(file))
#     191         else:
# --> 192             self._do_train(world_size)
#     193
#     194     def _setup_ddp(self, world_size):
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/trainer.py in _do_train(self, world_size)
#     347                 losses = self.tloss if loss_len > 1 else torch.unsqueeze(self.tloss, 0)
#     348                 if RANK in (-1, 0):
# --> 349                     pbar.set_description(
#     350                         ('%11s' * 2 + '%11.4g' * (2 + loss_len)) %
#     351                         (f'{epoch + 1}/{self.epochs}', mem, *losses, batch['cls'].shape[0], batch['img'].shape[-1]))
#
# /usr/local/lib/python3.10/dist-packages/tqdm/std.py in set_description(self, desc, refresh)
#    1389         self.desc = desc + ': ' if desc else ''
#    1390         if refresh:
# -> 1391             self.refresh()
#    1392
#    1393     def set_description_str(self, desc=None, refresh=True):
#
# /usr/local/lib/python3.10/dist-packages/tqdm/std.py in refresh(self, nolock, lock_args)
#    1342             else:
#    1343                 self._lock.acquire()
# -> 1344         self.display()
#    1345         if not nolock:
#    1346             self._lock.release()
#
# /usr/local/lib/python3.10/dist-packages/tqdm/std.py in display(self, msg, pos)
#    1490         if pos:
#    1491             self.moveto(pos)
# -> 1492         self.sp(self.__str__() if msg is None else msg)
#    1493         if pos:
#    1494             self.moveto(-pos)
#
# /usr/local/lib/python3.10/dist-packages/tqdm/std.py in print_status(s)
#     345         def print_status(s):
#     346             len_s = disp_len(s)
# --> 347             fp_write('\r' + s + (' ' * max(last_len[0] - len_s, 0)))
#     348             last_len[0] = len_s
#     349
#
# /usr/local/lib/python3.10/dist-packages/tqdm/std.py in fp_write(s)
#     339         def fp_write(s):
#     340             fp.write(str(s))
# --> 341             fp_flush()
#     342
#     343         last_len = [0]
#
# /usr/local/lib/python3.10/dist-packages/tqdm/utils.py in inner(*args, **kwargs)
#     125         def inner(*args, **kwargs):
#     126             try:
# --> 127                 return func(*args, **kwargs)
#     128             except OSError as e:
#     129                 if e.errno != 5:
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/iostream.py in flush(self)
#     348                 self.pub_thread.schedule(evt.set)
#     349                 # and give a timeout to avoid
# --> 350                 if not evt.wait(self.flush_timeout):
#     351                     # write directly to __stderr__ instead of warning because
#     352                     # if this is happening sys.stderr may be the problem.
#
# /usr/lib/python3.10/threading.py in wait(self, timeout)
#     605             signaled = self._flag
#     606             if not signaled:
# --> 607                 signaled = self._cond.wait(timeout)
#     608             return signaled
#     609
#
# /usr/lib/python3.10/threading.py in wait(self, timeout)
#     322             else:
#     323                 if timeout > 0:
# --> 324                     gotit = waiter.acquire(True, timeout)
#     325                 else:
#     326                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
# resuming model from it's last checkpoint
model.train(resume = True)
# Out:
# Ultralytics YOLOv8.0.115 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# yolo/engine/trainer: task=detect, mode=train, model=/content/drive/MyDrive/Violence_data/final_filter_vio_sh/train2/weights/best.pt, data=/content/drive/MyDrive/Violence_data/vio_filter.yaml, epochs=100, patience=50, batch=64, imgsz=416, save=True, save_period=-1, cache=False, device=None, workers=8, project=/content/drive/MyDrive/Violence_data/final_filter_vio_sh, name=None, exist_ok=False, pretrained=False, optimizer=Adamax, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=True, close_mosaic=0, resume=False, amp=True, fraction=1.0, profile=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=False, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_width=None, visualize=False, augment=True, agnostic_nms=True, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.001, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.8, hsv_s=0.8, hsv_v=0.8, degrees=1.0, translate=1.0, scale=0.9, shear=0.8, perspective=0.0, flipud=1.0, fliplr=1.0, mosaic=1.0, mixup=1.0, copy_paste=0.9, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=/content/drive/MyDrive/Violence_data/final_filter_vio_sh/train2
# TensorBoard: Start with 'tensorboard --logdir /content/drive/MyDrive/Violence_data/final_filter_vio_sh/train2', view at http://localhost:6006/
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2116435  ultralytics.nn.modules.head.Detect           [1, [128, 256, 512]]
# Model summary: 225 layers, 11135987 parameters, 11135971 gradients
#
# Transferred 355/355 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# train: Scanning /content/content/VIO_2/train/labels.cache... 7047 images, 0 backgrounds, 0 corrupt: 100%|██████████| 7047/7047 [00:00<?, ?it/s]
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/content/VIO_2/valid/labels.cache... 112 images, 0 backgrounds, 0 corrupt: 100%|██████████| 112/112 [00:00<?, ?it/s]
# Plotting labels to /content/drive/MyDrive/Violence_data/final_filter_vio_sh/train2/labels.jpg...
# optimizer: Adamax(lr=0.001, momentum=0.937) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Resuming training from /content/drive/MyDrive/Violence_data/final_filter_vio_sh/train2/weights/best.pt from epoch 54 to 100 total epochs
# Image sizes 416 train, 416 val
# Using 2 dataloader workers
# Logging results to /content/drive/MyDrive/Violence_data/final_filter_vio_sh/train2
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      7.33G      1.148     0.9712      1.374         18        416: 100%|██████████| 111/111 [02:47<00:00,  1.51s/it]
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      7.46G      1.145     0.9749      1.361        164        416:  82%|████████▏ | 91/111 [02:19<00:27,  1.38s/it]

# %%
#  validate model in single step
model.val(plots = True)
# Out:
# Ultralytics YOLOv8.0.115 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients
# val: Scanning /content/content/VIO_2/valid/labels.cache... 112 images, 0 backgrounds, 0 corrupt: 100%|██████████| 112/112 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:06<00:00,  1.01it/s]
#                    all        112        117      0.713       0.68      0.699      0.329
# Speed: 4.1ms preprocess, 7.2ms inference, 0.0ms loss, 9.0ms postprocess per image
# Results saved to runs/detect/val4
# ultralytics.yolo.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.yolo.utils.metrics.Metric object
# confusion_matrix: <ultralytics.yolo.utils.metrics.ConfusionMatrix object at 0x7fb788600f70>
# fitness: 0.36634237747232096
# keys: ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
# maps: array([    0.32933])
# names: {0: 'violence'}
# plot: True
# results_dict: {'metrics/precision(B)': 0.7132738518033171, 'metrics/recall(B)': 0.6804007814152884, 'metrics/mAP50(B)': 0.6994350298583756, 'metrics/mAP50-95(B)': 0.3293320827627593, 'fitness': 0.36634237747232096}
# save_dir: PosixPath('runs/detect/val4')
# speed: {'preprocess': 4.08771208354405, 'inference': 7.240667939186096, 'loss': 0.0012027365820748465, 'postprocess': 8.99040060383933}

# %%
vio_aug = model("https://cdn.images.express.co.uk/img/dynamic/78/590x/London-protest-trump-756980.jpg")

# %%
#  using predict method to predict imgs and also save it with it's boxes
model.predict(source = '/content/London-protest-trump-756980.jpg' , save = True )

# %%
img = vio_aug[0].plot()
# img = plt.imshow(img,cmap='gray')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %% [markdown]
# ## testing another | pretrained violence

# %%
results = YOLO("/content/drive/MyDrive/Violence_data/final_filter_vio_sh/train3/weights/last.pt")

# %%
results.train(resume = True)
# Out:
# Ultralytics YOLOv8.0.115 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# yolo/engine/trainer: task=detect, mode=train, model=/content/drive/MyDrive/Violence_data/final_filter_vio_sh/train3/weights/last.pt, data=/content/drive/MyDrive/Violence_data/vio_filter.yaml, epochs=100, patience=50, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=/content/drive/MyDrive/Violence_data/final_filter_vio_sh, name=None, exist_ok=False, pretrained=False, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=True, close_mosaic=0, resume=False, amp=True, fraction=1.0, profile=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=False, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, show=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, vid_stride=1, line_width=None, visualize=False, augment=True, agnostic_nms=True, classes=None, retina_masks=False, boxes=True, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.0, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=1.0, translate=0.6, scale=0.5, shear=0.5, perspective=0.0, flipud=0.6, fliplr=0.5, mosaic=1.0, mixup=0.9, copy_paste=0.4, cfg=None, v5loader=False, tracker=botsort.yaml, save_dir=/content/drive/MyDrive/Violence_data/final_filter_vio_sh/train3
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100%|██████████| 755k/755k [00:00<00:00, 29.8MB/s]
# TensorBoard: Start with 'tensorboard --logdir /content/drive/MyDrive/Violence_data/final_filter_vio_sh/train3', view at http://localhost:6006/
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1    664320  ultralytics.nn.modules.conv.Conv             [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1   1991808  ultralytics.nn.modules.conv.Conv             [384, 576, 3, 2]
#   8                  -1  2   3985920  ultralytics.nn.modules.block.C2f             [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  16                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  2   1846272  ultralytics.nn.modules.block.C2f             [576, 384, 2]
#  19                  -1  1   1327872  ultralytics.nn.modules.conv.Conv             [384, 384, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  2   4207104  ultralytics.nn.modules.block.C2f             [960, 576, 2]
#  22        [15, 18, 21]  1   3776275  ultralytics.nn.modules.head.Detect           [1, [192, 384, 576]]
# Model summary: 295 layers, 25856899 parameters, 25856883 gradients
#
# Transferred 475/475 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt to yolov8n.pt...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 157MB/s]
# AMP: checks passed ✅
# train: Scanning /content/VIO_2/train/labels... 8000 images, 953 backgrounds, 0 corrupt: 100%|██████████| 8000/8000 [00:07<00:00, 1054.72it/s]
# train: New cache created: /content/VIO_2/train/labels.cache
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/VIO_2/valid/labels... 112 images, 0 backgrounds, 0 corrupt: 100%|██████████| 112/112 [00:00<00:00, 1482.98it/s]
# val: New cache created: /content/VIO_2/valid/labels.cache
# Plotting labels to /content/drive/MyDrive/Violence_data/final_filter_vio_sh/train3/labels.jpg...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 77 weight(decay=0.0), 84 weight(decay=0.0005), 83 bias(decay=0.0)
# Resuming training from /content/drive/MyDrive/Violence_data/final_filter_vio_sh/train3/weights/last.pt from epoch 4 to 100 total epochs
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to /content/drive/MyDrive/Violence_data/final_filter_vio_sh/train3
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      6.95G      1.689      2.037       2.03         43        640: 100%|██████████| 500/500 [06:04<00:00,  1.37it/s]
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100      6.97G      1.661      2.014      2.018         49        640: 100%|██████████| 500/500 [05:56<00:00,  1.40it/s]
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100         7G      1.609      1.915       1.98         46        640: 100%|██████████| 500/500 [05:55<00:00,  1.41it/s]
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      6.99G      1.577      1.886       1.96         51        640: 100%|██████████| 500/500 [05:53<00:00,  1.41it/s]
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      6.99G      1.551      1.814      1.931         57        640: 100%|██████████| 500/500 [05:55<00:00,  1.40it/s]
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      6.99G      1.532      1.786      1.914         47        640: 100%|██████████| 500/500 [05:53<00:00,  1.42it/s]
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      6.99G      1.513      1.748      1.899         44        640: 100%|██████████| 500/500 [05:53<00:00,  1.41it/s]
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      6.99G      1.502      1.721      1.886         32        640: 100%|██████████| 500/500 [05:53<00:00,  1.42it/s]
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100         7G      1.473      1.664      1.854         51        640: 100%|██████████| 500/500 [05:56<00:00,  1.40it/s]
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100         7G      1.469      1.631      1.845         50        640: 100%|██████████| 500/500 [05:50<00:00,  1.43it/s]
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      6.99G      1.464      1.611       1.84         47        640: 100%|██████████| 500/500 [05:50<00:00,  1.43it/s]
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      6.99G      1.438      1.578      1.818         53        640: 100%|██████████| 500/500 [05:51<00:00,  1.42it/s]
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100         7G      1.437      1.537      1.817         40        640: 100%|██████████| 500/500 [05:55<00:00,  1.40it/s]
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      6.99G      1.424      1.549      1.809         53        640: 100%|██████████| 500/500 [05:54<00:00,  1.41it/s]
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      6.99G      1.414       1.51      1.796         44        640: 100%|██████████| 500/500 [05:52<00:00,  1.42it/s]
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100         7G      1.408      1.518       1.79         45        640: 100%|██████████| 500/500 [05:54<00:00,  1.41it/s]
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100         7G       1.39       1.47      1.786         43        640: 100%|██████████| 500/500 [05:56<00:00,  1.40it/s]
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      6.99G      1.388      1.469      1.776         45        640: 100%|██████████| 500/500 [06:05<00:00,  1.37it/s]
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      6.99G      1.384      1.438      1.768         51        640: 100%|██████████| 500/500 [05:59<00:00,  1.39it/s]
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      7.01G      1.371       1.42      1.754         46        640: 100%|██████████| 500/500 [05:58<00:00,  1.40it/s]
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      6.99G      1.357      1.442      1.743         39        640:  20%|█▉        | 98/500 [01:11<04:54,  1.36it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-d53824e78dd5> in <cell line: 1>()
# ----> 1 results.train(resume = True)
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/model.py in train(self, **kwargs)
#     369             self.model = self.trainer.model
#     370         self.trainer.hub_session = self.session  # attach optional HUB session
# --> 371         self.trainer.train()
#     372         # Update model and cfg after training
#     373         if RANK in (-1, 0):
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/trainer.py in train(self)
#     190                 ddp_cleanup(self, str(file))
#     191         else:
# --> 192             self._do_train(world_size)
#     193
#     194     def _setup_ddp(self, world_size):
#
# /usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/trainer.py in _do_train(self, world_size)
#     347                 losses = self.tloss if loss_len > 1 else torch.unsqueeze(self.tloss, 0)
#     348                 if RANK in (-1, 0):
# --> 349                     pbar.set_description(
#     350                         ('%11s' * 2 + '%11.4g' * (2 + loss_len)) %
#     351                         (f'{epoch + 1}/{self.epochs}', mem, *losses, batch['cls'].shape[0], batch['img'].shape[-1]))
#
# /usr/local/lib/python3.10/dist-packages/tqdm/std.py in set_description(self, desc, refresh)
#    1377         self.refresh()
#    1378
# -> 1379     def set_description(self, desc=None, refresh=True):
#    1380         """
#    1381         Set/modify description of the progress bar.
#
# KeyboardInterrupt:

# %%
results.val(plots = True)
# Out:
# Ultralytics YOLOv8.0.115 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25840339 parameters, 0 gradients
# val: Scanning /content/VIO_2/valid/labels.cache... 112 images, 0 backgrounds, 0 corrupt: 100%|██████████| 112/112 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:08<00:00,  1.21s/it]
#                    all        112        117      0.844      0.709       0.82      0.462
# Speed: 9.5ms preprocess, 22.0ms inference, 0.0ms loss, 7.8ms postprocess per image
# Results saved to runs/detect/val3
# ultralytics.yolo.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0])
# box: ultralytics.yolo.utils.metrics.Metric object
# confusion_matrix: <ultralytics.yolo.utils.metrics.ConfusionMatrix object at 0x7fefe32d60e0>
# fitness: 0.49772808187842504
# keys: ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
# maps: array([    0.46192])
# names: {0: 'violence'}
# plot: True
# results_dict: {'metrics/precision(B)': 0.8440287744038621, 'metrics/recall(B)': 0.7094017094017094, 'metrics/mAP50(B)': 0.8199796228524264, 'metrics/mAP50-95(B)': 0.46192235510353596, 'fitness': 0.49772808187842504}
# save_dir: PosixPath('runs/detect/val3')
# speed: {'preprocess': 9.460289563451495, 'inference': 22.03937300613948, 'loss': 0.0012942722865513393, 'postprocess': 7.822730711528234}

# %%
model = YOLO("/content/drive/MyDrive/yolov8_test/run_with_augment/train/weights/best.pt")

# %%
model.predict(source="/content/self_caps_imgs" , save=True , save_txt = True)

# %%
res = model("/content/IMG_20230610_175406.jpg")
# Out:
# image 1/1 /content/IMG_20230610_175406.jpg: 640x480 1 violence, 146.6ms
# Speed: 4.1ms preprocess, 146.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)

# %%
img = res[0].plot()
# img = plt.imshow(img,cmap='gray')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %%
# %cp -r /content/runs/detect/predict/VID_20230420_192106.mp4 drive/MyDrive/yolov8_test

# %%
results = model('/content/VID_20230420_192106.mp4')

# %%
# !python /content/yolov5/detect.py --weights /content/drive/MyDrive/best.pt --source /content/VID_20230420_192106.mp4

# %%
# !zip "/content/labels.zip" -r "/content/runs/detect/predict"

# %% [markdown]
# ## Testing weapons class + how to predict on videos

# %%
wep = YOLO("/content/drive/MyDrive/test/train6/weights/best.pt")

# %%
# predict on videos
results = wep.predict(source = "/content/guns.mp4" , save = True , agnostic_nms = True )
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/207) /content/guns.mp4: 256x416 2 weponss, 31.5ms
# video 1/1 (2/207) /content/guns.mp4: 256x416 2 weponss, 11.2ms
# video 1/1 (3/207) /content/guns.mp4: 256x416 2 weponss, 9.7ms
# video 1/1 (4/207) /content/guns.mp4: 256x416 2 weponss, 10.7ms
# video 1/1 (5/207) /content/guns.mp4: 256x416 1 wepons, 12.0ms
# video 1/1 (6/207) /content/guns.mp4: 256x416 2 weponss, 13.1ms
# video 1/1 (7/207) /content/guns.mp4: 256x416 1 wepons, 11.3ms
# video 1/1 (8/207) /content/guns.mp4: 256x416 2 weponss, 10.4ms
# video 1/1 (9/207) /content/guns.mp4: 256x416 1 wepons, 11.2ms
# video 1/1 (10/207) /content/guns.mp4: 256x416 1 wepons, 9.1ms
# video 1/1 (11/207) /content/guns.mp4: 256x416 1 wepons, 8.2ms
# video 1/1 (12/207) /content/guns.mp4: 256x416 2 weponss, 7.9ms
# video 1/1 (13/207) /content/guns.mp4: 256x416 2 weponss, 8.4ms
# video 1/1 (14/207) /content/guns.mp4: 256x416 2 weponss, 8.1ms
# video 1/1 (15/207) /content/guns.mp4: 256x416 2 weponss, 9.3ms
# video 1/1 (16/207) /content/guns.mp4: 256x416 1 wepons, 10.0ms
# video 1/1 (17/207) /content/guns.mp4: 256x416 1 wepons, 8.3ms
# video 1/1 (18/207) /content/guns.mp4: 256x416 1 wepons, 8.5ms
# video 1/1 (19/207) /content/guns.mp4: 256x416 1 wepons, 8.2ms
# video 1/1 (20/207) /content/guns.mp4: 256x416 1 wepons, 8.0ms
# video 1/1 (21/207) /content/guns.mp4: 256x416 1 wepons, 9.7ms
# video 1/1 (22/207) /content/guns.mp4: 256x416 1 wepons, 7.8ms
# video 1/1 (23/207) /content/guns.mp4: 256x416 1 wepons, 8.0ms
# video 1/1 (24/207) /content/guns.mp4: 256x416 1 wepons, 8.0ms
# video 1/1 
207) /content/guns.mp4: 256x416 1 wepons, 7.8ms
# video 1/1 (199/207) /content/guns.mp4: 256x416 1 wepons, 9.0ms
# video 1/1 (200/207) /content/guns.mp4: 256x416 1 wepons, 7.9ms
# video 1/1 (201/207) /content/guns.mp4: 256x416 1 wepons, 9.4ms
# video 1/1 (202/207) /content/guns.mp4: 256x416 1 wepons, 8.6ms
# video 1/1 (203/207) /content/guns.mp4: 256x416 1 wepons, 7.8ms
# video 1/1 (204/207) /content/guns.mp4: 256x416 1 wepons, 7.8ms
# Speed: 1.6ms preprocess, 9.0ms inference, 1.6ms postprocess per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/predict2

# %%
rwep = wep("https://as2.ftcdn.net/v2/jpg/00/73/46/33/1000_F_73463362_cMxSd7Gm5z7kZmSCnSJLQ7GEqlnP9roc.jpg")
# Out:
# Found https://as2.ftcdn.net/v2/jpg/00/73/46/33/1000_F_73463362_cMxSd7Gm5z7kZmSCnSJLQ7GEqlnP9roc.jpg locally at 1000_F_73463362_cMxSd7Gm5z7kZmSCnSJLQ7GEqlnP9roc.jpg
# image 1/1 /content/1000_F_73463362_cMxSd7Gm5z7kZmSCnSJLQ7GEqlnP9roc.jpg: 288x416 1 wepons, 15.0ms
# Speed: 1.2ms preprocess, 15.0ms inference, 1.7ms postprocess per image at shape (1, 3, 416, 416)

# %%
box = results2[0].boxes
box.conf
box.cls[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-979c0c38d7eb> in <cell line: 1>()
# ----> 1 box = results2[0].boxes
#       2 box.conf
#       3 box.cls[0]
#
# NameError: name 'results2' is not defined

# %%
img = rwep[0].plot()
# img = plt.imshow(img,cmap='gray')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %% [markdown]
# ## testing weapon & violence class

# %%
wv = YOLO("/content/drive/MyDrive/test/train4/weights/best.pt")

# %%
results = wv.predict(source = "/content/main-qimg-29be627d7e8429acd67dda6b15975a14-lq.jpeg" , save = True , agnostic_nms = True )
# Out:
# image 1/1 /content/main-qimg-29be627d7e8429acd67dda6b15975a14-lq.jpeg: 288x416 1 Weapon, 10.2ms
# Speed: 1.4ms preprocess, 10.2ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/predict2

# %%
resvw = wv("https://assets.rbl.ms/22920864/origin.jpg")
# Out:
# Downloading https://assets.rbl.ms/22920864/origin.jpg to origin.jpg...
# 100%|██████████| 64.8k/64.8k [00:00<00:00, 12.6MB/s]
# image 1/1 /content/origin.jpg: 416x384 1 Violence, 1 Weapon, 337.1ms
# Speed: 2.0ms preprocess, 337.1ms inference, 5.9ms postprocess per image at shape (1, 3, 416, 416)

# %%
class_name = np.array([
    'Violence' ,
    'Weapon' ,
    'Fire' ,
    'Smoke'
])

# %%
results = results[0].cuda()
results = results.cpu()
results = results.to('cpu')
results = results.numpy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-b14d6c45c50d> in <cell line: 1>()
# ----> 1 results = results[0].cuda()
#       2 results = results.cpu()
#       3 results = results.to('cpu')
#       4 results = results.numpy()
#
# NameError: name 'results' is not defined

# %%
import numpy as np
box = resvw[0].boxes


cls = box.cls.tolist()
cls = list(map(int ,cls))
print(class_name[cls])

print(cls)
print(box.conf)
# for i in range(len(box.conf)):
#     print(f" the image has {class_name[i]} object on it")
# Out:
# ['Weapon' 'Violence']
# [1, 0]
# tensor([0.8410, 0.7586], device='cuda:0')

# %%
img = resvw[0].plot()
# img = plt.imshow(img,cmap='gray')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %% [markdown]
# ## testing fire_smoke model

# %%
fs_model = YOLO("/content/drive/MyDrive/test/final_fire&smoke_run/train/weights/best.pt")

# %%
fr_res = fs_model.predict(source = "/content/fire_smoke.mp4" , save = True  )
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/223) /content/fire_smoke.mp4: 256x416 2 fires, 24.5ms
# video 1/1 (2/223) /content/fire_smoke.mp4: 256x416 2 fires, 15.8ms
# video 1/1 (3/223) /content/fire_smoke.mp4: 256x416 2 fires, 22.4ms
# video 1/1 (4/223) /content/fire_smoke.mp4: 256x416 3 fires, 1 smoke, 22.9ms
# video 1/1 (5/223) /content/fire_smoke.mp4: 256x416 2 fires, 1 smoke, 21.3ms
# video 1/1 (6/223) /content/fire_smoke.mp4: 256x416 2 fires, 46.4ms
# video 1/1 (7/223) /content/fire_smoke.mp4: 256x416 2 fires, 1 smoke, 41.0ms
# video 1/1 (8/223) /content/fire_smoke.mp4: 256x416 3 fires, 1 smoke, 19.2ms
# video 1/1 (9/223) /content/fire_smoke.mp4: 256x416 2 fires, 1 smoke, 15.5ms
# video 1/1 (10/223) /content/fire_smoke.mp4: 256x416 2 fires, 43.9ms
# video 1/1 (11/223) /content/fire_smoke.mp4: 256x416 1 fire, 13.1ms
# video 1/1 (12/223) /content/fire_smoke.mp4: 256x416 2 fires, 2 smokes, 25.2ms
# video 1/1 (13/223) /content/fire_smoke.mp4: 256x416 1 fire, 2 smokes, 15.7ms
# video 1/1 (14/223) /content/fire_smoke.mp4: 256x416 3 fires, 1 smoke, 13.7ms
# video 1/1 (15/223) /content/fire_smoke.mp4: 256x416 3 fires, 1 smoke, 10.9ms
# video 1/1 (16/223) /content/fire_smoke.mp4: 256x416 1 fire, 1 smoke, 15.3ms
# video 1/1 (17/223) /content/fire_smoke.mp4: 256x416 1 fire, 16.8ms
# video 1/1 (18/223) /content/fire_smoke.mp4: 256x416 1 fire, 25.4ms
# video 1/1 (19/223) /content/fire_smoke.mp4: 256x416 2 fires, 28.7ms
# video 1/1 (20/223) /content/fire_smoke.mp4: 256x416 1 fire, 1 smoke, 43.1ms
# video 1/1 (21/223) /content/fire_smoke.mp4: 256x416 1 fire, 57.5ms
# video 1/1 (22/223) /content/fire_smoke.mp4: 256x416 1 fire, 55.7ms
# video 1/1 (23/223) /content/fire_smoke.mp4: 256x416 1 fire, 86.1ms
# video 1/1 (24/223) /content/fire_smoke.mp4: 256x416 1 fire, 54.4ms
# video 1/1 (25/223) /content/fire_smoke.mp4: 256x416 1 fire, 42.6ms
# video 1/1 (26/223) /content/fire_smoke.mp4: 256x416 1 fire, 28.2ms
# video 1/1 (27/223) /content/fire_smoke.mp4: 256x416 1 fire, 1 smoke, 18.4ms
# video 1/1 (28/223) /content/fire_smoke.mp4: 256x416 1 fire, 1 smoke, 19.4ms
# video 1/1 (29/223) /content/fire_smoke.mp4: 256x416 1 fire, 1 smoke, 12.3ms
# video 1/1 (30/223) /content/fire_smoke.mp4: 256x416 2 fires, 1 smoke, 11.5ms
# video 1/1 (31/223) /content/fire_smoke.mp4: 256x416 1 fire, 1 smoke, 11.2ms
# video 1/1 (32/223) /content/fire_smoke.mp4: 256x416 1 fire, 8.0ms
# video 1/1 (33/223) /content/fire_smoke.mp4: 256x416 1 fire, 1 smoke, 10.3ms
# video 1/1 (34/223) /content/fire_smoke.mp4: 256x416 1 fire, 8.5ms
# video 1/1 (35/223) /content/fire_smoke.mp4: 256x416 1 fire, 12.6ms
# video 1/1 (36/223) /content/fire_smoke.mp4: 256x416 1 fire, 8.6ms
# video 1/1 (37/223) /content/fire_smoke.mp4: 256x416 2 fires, 2 smokes, 9.0ms
# video 1/1 (38/223) /content/fire_smoke.mp4: 256x416 2 fires, 8.5ms
# video 1/1 (39/223) /content/fire_smoke.mp4: 256x416 2 fires, 11.1ms
# video 1/1 (40/223) /content/fire_smoke.mp4: 256x416 1 fire, 8.5ms
# video 1/1 (41/223) /content/fire_smoke.mp4: 256x416 1 fire, 11.4ms
# video 1/1 (42/223) /content/fire_smoke.mp4: 256x416 1 fire, 1 smoke, 8.1ms
# video 1/1 (43/223) /content/fire_smoke.mp4: 256x416 1 fire, 1 smoke, 10.6ms
# video 1/1 (44/223) /content/fire_smoke.mp4: 256x416 1 fire, 1 smoke, 8.2ms
# video 1/1 (45/223) /content/fire_smoke.mp4: 256x416 1 fire, 1 smoke, 11.0ms
# video 1/1 (46/223) /content/fire_smoke.mp4: 256x416 1 fire, 1 smoke, 8.2ms
# video 1/1 (47/223) /content/fire_smoke.mp4: 256x416 1 fire, 1 smoke, 12.0ms
# video 1/1 (48/223) /content/fire_smoke.mp4: 256x416 1 fire, 1 smoke, 8.7ms
# video 1/1 (49/223) /content/fire_smoke.mp4: 256x416 1 fire, 1 smoke, 11.2ms
# video 1/1 (50/223) /content/fire_smoke.mp4: 256x416 1 fire, 8.1ms
# video 1/1 (51/223) /content/fire_smoke.mp4: 256x416 1 fire, 11.3ms
# video 1/1 (52/223) /content/fire_smoke.mp4: 256x416 1 fire, 8.3ms
# video 1/1 (53/223) /content/fire_smoke.mp4: 256x416 1 fire, 1 smoke,
223) /content/fire_smoke.mp4: 256x416 2 fires, 1 smoke, 8.3ms
# video 1/1 (193/223) /content/fire_smoke.mp4: 256x416 2 fires, 1 smoke, 7.9ms
# video 1/1 (194/223) /content/fire_smoke.mp4: 256x416 2 fires, 1 smoke, 8.1ms
# video 1/1 (195/223) /content/fire_smoke.mp4: 256x416 3 fires, 1 smoke, 8.0ms
# video 1/1 (196/223) /content/fire_smoke.mp4: 256x416 1 fire, 1 smoke, 9.8ms
# video 1/1 (197/223) /content/fire_smoke.mp4: 256x416 2 fires, 1 smoke, 8.9ms
# video 1/1 (198/223) /content/fire_smoke.mp4: 256x416 2 fires, 1 smoke, 9.9ms
# video 1/1 (199/223) /content/fire_smoke.mp4: 256x416 2 fires, 1 smoke, 9.9ms
# video 1/1 (200/223) /content/fire_smoke.mp4: 256x416 1 fire, 2 smokes, 10.2ms
# video 1/1 (201/223) /content/fire_smoke.mp4: 256x416 1 fire, 1 smoke, 8.4ms
# video 1/1 (202/223) /content/fire_smoke.mp4: 256x416 1 fire, 1 smoke, 9.7ms
# video 1/1 (203/223) /content/fire_smoke.mp4: 256x416 1 fire, 1 smoke, 10.6ms
# video 1/1 (204/223) /content/fire_smoke.mp4: 256x416 1 fire, 1 smoke, 9.8ms
# video 1/1 (205/223) /content/fire_smoke.mp4: 256x416 2 fires, 1 smoke, 8.1ms
# video 1/1 (206/223) /content/fire_smoke.mp4: 256x416 2 fires, 1 smoke, 10.1ms
# video 1/1 (207/223) /content/fire_smoke.mp4: 256x416 1 fire, 1 smoke, 7.8ms
# video 1/1 (208/223) /content/fire_smoke.mp4: 256x416 1 fire, 1 smoke, 8.4ms
# video 1/1 (209/223) /content/fire_smoke.mp4: 256x416 1 fire, 1 smoke, 9.6ms
# video 1/1 (210/223) /content/fire_smoke.mp4: 256x416 2 fires, 2 smokes, 8.1ms
# video 1/1 (211/223) /content/fire_smoke.mp4: 256x416 1 fire, 2 smokes, 9.4ms
# video 1/1 (212/223) /content/fire_smoke.mp4: 256x416 2 fires, 1 smoke, 7.8ms
# video 1/1 (213/223) /content/fire_smoke.mp4: 256x416 2 fires, 1 smoke, 10.2ms
# video 1/1 (214/223) /content/fire_smoke.mp4: 256x416 1 fire, 2 smokes, 9.5ms
# video 1/1 (215/223) /content/fire_smoke.mp4: 256x416 3 fires, 2 smokes, 8.7ms
# video 1/1 (216/223) /content/fire_smoke.mp4: 256x416 3 fires, 1 smoke, 9.0ms
# video 1/1 (217/223) /content/fire_smoke.mp4: 256x416 3 fires, 1 smoke, 9.3ms
# video 1/1 (218/223) /content/fire_smoke.mp4: 256x416 2 fires, 1 smoke, 9.0ms
# Speed: 2.2ms preprocess, 12.2ms inference, 2.3ms postprocess per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/predict

# %%
fr_res = fs_model("https://www.bankrate.com/2022/04/19102915/House-fire-statistics.jpg")
# Out:
# Downloading https://www.bankrate.com/2022/04/19102915/House-fire-statistics.jpg to House-fire-statistics.jpg...
# 100%|██████████| 106k/106k [00:00<00:00, 9.08MB/s]
# image 1/1 /content/House-fire-statistics.jpg: 256x416 4 fires, 119.3ms
# Speed: 1.8ms preprocess, 119.3ms inference, 2.3ms postprocess per image at shape (1, 3, 416, 416)

# %%
img = fr_res[0].plot()
# img = plt.imshow(img,cmap='gray')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %% [markdown]
# ## Weapon , Violence , Fire , Smoke model

# %%
model = YOLO("/content/drive/MyDrive/test/train6/val2/train/weights/best.pt")

# %%
fswv = model("/content/Screenshot 2023-06-20 233324.png")
# Out:
# image 1/1 /content/Screenshot 2023-06-20 233324.png: 256x416 (no detections), 10.3ms
# Speed: 2.5ms preprocess, 10.3ms inference, 0.8ms postprocess per image at shape (1, 3, 416, 416)

# %%
model.predict(source = "/content/fire_smoke.mp4" , save = True , agnostic_nms = True)
# Out:
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/223) /content/fire_smoke.mp4: 256x416 2 Fires, 10.5ms
# video 1/1 (2/223) /content/fire_smoke.mp4: 256x416 2 Fires, 8.9ms
# video 1/1 (3/223) /content/fire_smoke.mp4: 256x416 2 Fires, 1 Smoke, 8.9ms
# video 1/1 (4/223) /content/fire_smoke.mp4: 256x416 2 Fires, 9.0ms
# video 1/1 (5/223) /content/fire_smoke.mp4: 256x416 2 Fires, 10.2ms
# video 1/1 (6/223) /content/fire_smoke.mp4: 256x416 2 Fires, 8.9ms
# video 1/1 (7/223) /content/fire_smoke.mp4: 256x416 2 Fires, 9.9ms
# video 1/1 (8/223) /content/fire_smoke.mp4: 256x416 2 Fires, 8.9ms
# video 1/1 (9/223) /content/fire_smoke.mp4: 256x416 1 Weapon, 1 Fire, 10.8ms
# video 1/1 (10/223) /content/fire_smoke.mp4: 256x416 2 Fires, 8.4ms
# video 1/1 (11/223) /content/fire_smoke.mp4: 256x416 2 Fires, 9.5ms
# video 1/1 (12/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 8.8ms
# video 1/1 (13/223) /content/fire_smoke.mp4: 256x416 3 Fires, 9.0ms
# video 1/1 (14/223) /content/fire_smoke.mp4: 256x416 2 Fires, 9.0ms
# video 1/1 (15/223) /content/fire_smoke.mp4: 256x416 2 Fires, 8
223) /content/fire_smoke.mp4: 256x416 2 Fires, 1 Smoke, 8.2ms
# video 1/1 (150/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 8.2ms
# video 1/1 (151/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 8.2ms
# video 1/1 (152/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 8.1ms
# video 1/1 (153/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 9.1ms
# video 1/1 (154/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 8.2ms
# video 1/1 (155/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 10.7ms
# video 1/1 (156/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 8.3ms
# video 1/1 (157/223) /content/fire_smoke.mp4: 256x416 1 Smoke, 10.6ms
# video 1/1 (158/223) /content/fire_smoke.mp4: 256x416 1 Smoke, 8.9ms
# video 1/1 (159/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 10.5ms
# video 1/1 (160/223) /content/fire_smoke.mp4: 256x416 1 Smoke, 8.1ms
# video 1/1 (161/223) /content/fire_smoke.mp4: 256x416 1 Smoke, 10.5ms
# video 1/1 (162/223) /content/fire_smoke.mp4: 256x416 1 Smoke, 8.3ms
# video 1/1 (163/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 9.0ms
# video 1/1 (164/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 8.1ms
# video 1/1 (165/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 11.9ms
# video 1/1 (166/223) /content/fire_smoke.mp4: 256x416 3 Fires, 1 Smoke, 11.6ms
# video 1/1 (167/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 9.4ms
# video 1/1 (168/223) /content/fire_smoke.mp4: 256x416 3 Fires, 1 Smoke, 8.7ms
# video 1/1 (169/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 8.1ms
# video 1/1 (170/223) /content/fire_smoke.mp4: 256x416 2 Fires, 1 Smoke, 9.2ms
# video 1/1 (171/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 8.2ms
# video 1/1 (172/223) /content/fire_smoke.mp4: 256x416 2 Fires, 1 Smoke, 10.4ms
# video 1/1 (173/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 10.4ms
# video 1/1 (174/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 10.6ms
# video 1/1 (175/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 10.8ms
# video 1/1 (176/223) /content/fire_smoke.mp4: 256x416 2 Fires, 1 Smoke, 12.5ms
# video 1/1 (177/223) /content/fire_smoke.mp4: 256x416 2 Fires, 1 Smoke, 11.1ms
# video 1/1 (178/223) /content/fire_smoke.mp4: 256x416 2 Fires, 1 Smoke, 10.8ms
# video 1/1 (179/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 8.5ms
# video 1/1 (180/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 11.2ms
# video 1/1 (181/223) /content/fire_smoke.mp4: 256x416 2 Fires, 1 Smoke, 12.7ms
# video 1/1 (182/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 11.8ms
# video 1/1 (183/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 10.2ms
# video 1/1 (184/223) /content/fire_smoke.mp4: 256x416 2 Fires, 1 Smoke, 11.3ms
# video 1/1 (185/223) /content/fire_smoke.mp4: 256x416 2 Fires, 1 Smoke, 11.7ms
# video 1/1 (186/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 11.0ms
# video 1/1 (187/223) /content/fire_smoke.mp4: 256x416 2 Fires, 1 Smoke, 10.6ms
# video 1/1 (188/223) /content/fire_smoke.mp4: 256x416 2 Fires, 1 Smoke, 11.3ms
# video 1/1 (189/223) /content/fire_smoke.mp4: 256x416 3 Fires, 1 Smoke, 10.0ms
# video 1/1 (190/223) /content/fire_smoke.mp4: 256x416 2 Fires, 1 Smoke, 9.0ms
# video 1/1 (191/223) /content/fire_smoke.mp4: 256x416 2 Fires, 1 Smoke, 8.2ms
# video 1/1 (192/223) /content/fire_smoke.mp4: 256x416 2 Fires, 1 Smoke, 8.2ms
# video 1/1 (193/223) /content/fire_smoke.mp4: 256x416 2 Fires, 1 Smoke, 9.7ms
# video 1/1 (194/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 8.3ms
# video 1/1 (195/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 8.5ms
# video 1/1 (196/223) /content/fire_smoke.mp4: 256x416 2 Fires, 1 Smoke, 8.6ms
# video 1/1 (197/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 8.9ms
# video 1/1 (198/223) /content/fire_smoke.mp4: 256x416 1 Smoke, 9.4ms
# video 1/1 (199/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 8.3ms
# video 1/1 (200/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 8.2ms
# video 1/1 (201/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 8.1ms
# video 1/1 (202/223) /content/fire_smoke.mp4: 256x416 1 Fire, 2 Smokes, 10.1ms
# video 1/1 (203/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 8.5ms
# video 1/1 (204/223) /content/fire_smoke.mp4: 256x416 2 Fires, 1 Smoke, 8.4ms
# video 1/1 (205/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 8.2ms
# video 1/1 (206/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 8.1ms
# video 1/1 (207/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 8.4ms
# video 1/1 (208/223) /content/fire_smoke.mp4: 256x416 2 Fires, 1 Smoke, 9.2ms
# video 1/1 (209/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 10.4ms
# video 1/1 (210/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 8.4ms
# video 1/1 (211/223) /content/fire_smoke.mp4: 256x416 2 Fires, 1 Smoke, 11.1ms
# video 1/1 (212/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 8.8ms
# video 1/1 (213/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 9.4ms
# video 1/1 (214/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 10.6ms
# video 1/1 (215/223) /content/fire_smoke.mp4: 256x416 2 Fires, 1 Smoke, 9.3ms
# video 1/1 (216/223) /content/fire_smoke.mp4: 256x416 1 Fire, 1 Smoke, 8.2ms
# video 1/1 (217/223) /content/fire_smoke.mp4: 256x416 5 Fires, 1 Smoke, 8.4ms
# video 1/1 (218/223) /content/fire_smoke.mp4: 256x416 2 Fires, 1 Smoke, 8.4ms
# Speed: 2.1ms preprocess, 10.0ms inference, 1.9ms postprocess per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/predict
# [ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[ 54,  54,  54],
#          [ 54,  54,  54],
#          [ 54,  54,  54],
#          ...,
#          [152, 146, 136],
#          [152, 146, 136],
#          [152, 146, 136]],
#
#         [[ 54,  54,  54],
#          [ 54,  54,  54],
#          [ 54,  54,  54],
#          ...,
#          [152, 146, 136],
#          [152, 146, 136],
#          [152, 146, 136]],
#
#         [[ 54,  54,  54],
#          [ 54,  54,  54],
#          [ 54,  54,  54],
#          ...,
#          [154, 148, 138],
#          [154, 148, 138],
#          [154, 148, 138]],
#
#         ...,
#
#         [[ 99, 108, 157],
#          [ 99, 108, 157],
#          [100, 109, 158],
#          ...,
#          [163, 169, 173],
#          [163, 169, 173],
#          [163, 169, 173]],
#
#         [[ 95, 104, 153],
#          [ 95, 104, 153],
#          [ 94, 103, 152],
#          ...,
#          [166, 172, 176],
#          [166, 172, 176],
#          [166, 172, 176]],
#
#         [[ 95, 104, 153],
#          [ 95, 104, 153],
#          [ 93, 102, 151],
#          ...,
#          [166, 172, 176],
#          [166, 172, 176],
#          [166, 172, 176]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.0418167114257812, 'inference': 10.480165481567383, 'postprocess': 1.583099365234375},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[ 50,  50,  50],
#          [ 50,  50,  50],
#          [ 48,  48,  48],
#          ...,
#          [184, 176, 166],
#          [188, 180, 170],
#          [192, 184, 174]],
#
#         [[ 50,  50,  50],
#          [ 50,  50,  50],
#          [ 48,  48,  48],
#          ...,
#          [199, 191, 181],
#          [203, 195, 185],
#          [205, 197, 187]],
#
#         [[ 50,  50,  50],
#          [ 50,  50,  50],
#          [ 48,  48,  48],
#          ...,
#          [200, 192, 180],
#          [203, 195, 183],
#          [204, 196, 184]],
#
#         ...,
#
#         [[ 52,  59, 126],
#          [ 52,  59, 126],
#          [ 52,  59, 126],
#          ...,
#          [ 42,  53, 115],
#          [ 42,  53, 115],
#          [ 42,  53, 115]],
#
#         [[ 58,  65, 132],
#          [ 58,  65, 132],
#          [ 58,  65, 132],
#          ...,
#          [ 41,  51, 121],
#          [ 41,  51, 121],
#          [ 41,  51, 121]],
#
#         [[ 63,  70, 137],
#          [ 63,  70, 137],
#          [ 63,  70, 137],
#          ...,
#          [ 34,  44, 114],
#          [ 34,  44, 114],
#          [ 34,  44, 114]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 1.7833709716796875, 'inference': 8.924722671508789, 'postprocess': 1.6758441925048828},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[ 44,  44,  44],
#          [ 44,  44,  44],
#          [ 44,  44,  44],
#          ...,
#          [200, 191, 183],
#          [200, 191, 183],
#          [200, 191, 183]],
#
#         [[ 44,  44,  44],
#          [ 44,  44,  44],
#          [ 44,  44,  44],
#          ...,
#          [190, 181, 173],
#          [190, 181, 173],
#          [190, 181, 173]],
#
#         [[ 44,  44,  44],
#          [ 44,  44,  44],
#          [ 44,  44,  44],
#          ...,
#          [169, 160, 152],
#          [169, 160, 152],
#          [169, 160, 152]],
#
#         ...,
#
#         [[ 63,  74, 129],
#          [ 62,  73, 128],
#          [ 64,  75, 130],
#          ...,
#          [163, 169, 173],
#          [163, 169, 173],
#          [163, 169, 173]],
#
#         [[ 68,  79, 134],
#          [ 67,  78, 133],
#          [ 69,  80, 135],
#          ...,
#          [163, 169, 173],
#          [166, 172, 176],
#          [166, 172, 176]],
#
#         [[ 68,  79, 134],
#          [ 67,  78, 133],
#          [ 69,  80, 135],
#          ...,
#          [163, 169, 173],
#          [166, 172, 176],
#          [166, 172, 176]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.041339874267578, 'inference': 8.931398391723633, 'postprocess': 1.560211181640625},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[ 68,  68,  68],
#          [ 69,  69,  69],
#          [ 67,  67,  67],
#          ...,
#          [197, 190, 175],
#          [197, 190, 175],
#          [196, 189, 174]],
#
#         [[ 64,  64,  64],
#          [ 65,  65,  65],
#          [ 62,  62,  62],
#          ...,
#          [197, 190, 175],
#          [196, 189, 174],
#          [196, 189, 174]],
#
#         [[ 53,  53,  53],
#          [ 54,  54,  54],
#          [ 52,  52,  52],
#          ...,
#          [195, 187, 177],
#          [195, 187, 177],
#          [192, 184, 174]],
#
#         ...,
#
#         [[ 44,  55, 110],
#          [ 44,  55, 110],
#          [ 44,  55, 110],
#          ...,
#          [151, 157, 161],
#          [149, 155, 159],
#          [151, 157, 161]],
#
#         [[ 42,  53, 108],
#          [ 42,  53, 108],
#          [ 42,  53, 108],
#          ...,
#          [160, 166, 170],
#          [158, 164, 168],
#          [160, 166, 170]],
#
#         [[ 42,  53, 108],
#          [ 42,  53, 108],
#          [ 42,  53, 108],
#          ...,
#          [151, 157, 161],
#          [150, 156, 160],
#          [151, 157, 161]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 1.6837120056152344, 'inference': 9.025096893310547, 'postprocess': 1.6565322875976562},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[ 41,  41,  41],
#          [ 43,  43,  43],
#          [ 43,  43,  43],
#          ...,
#          [183, 174, 166],
#          [190, 181, 173],
#          [191, 182, 174]],
#
#         [[ 41,  41,  41],
#          [ 43,  43,  43],
#          [ 43,  43,  43],
#          ...,
#          [192, 183, 175],
#          [193, 184, 176],
#          [195, 186, 178]],
#
#         [[ 41,  41,  41],
#          [ 43,  43,  43],
#          [ 43,  43,  43],
#          ...,
#          [199, 187, 180],
#          [199, 187, 180],
#          [199, 187, 180]],
#
#         ...,
#
#         [[ 46,  57, 112],
#          [ 46,  57, 112],
#          [ 46,  57, 112],
#          ...,
#          [169, 175, 179],
#          [204, 210, 214],
#          [222, 228, 232]],
#
#         [[ 42,  53, 108],
#          [ 42,  53, 108],
#          [ 40,  51, 106],
#          ...,
#          [181, 187, 191],
#          [186, 192, 196],
#          [190, 196, 200]],
#
#         [[ 42,  53, 108],
#          [ 42,  53, 108],
#          [ 39,  50, 105],
#          ...,
#          [178, 184, 188],
#          [171, 177, 181],
#          [167, 173, 177]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 1.9922256469726562, 'inference': 10.213613510131836, 'postprocess': 1.5935897827148438},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[ 43,  43,  43],
#          [ 44,  44,  44],
#          [ 44,  44,  44],
#          ...,
#          [191, 182, 174],
#          [191, 182, 174],
#          [191, 182, 174]],
#
#         [[ 43,  43,  43],
#          [ 44,  44,  44],
#          [ 44,  44,  44],
#          ...,
#          [192, 183, 175],
#          [192, 183, 175],
#          [192, 183, 175]],
#
#         [[ 44,  44,  44],
#          [ 44,  44,  44],
#          [ 44,  44,  44],
#          ...,
#          [198, 186, 179],
#          [198, 186, 179],
#          [198, 186, 179]],
#
#         ...,
#
#         [[ 51,  64, 126],
#          [ 54,  67, 129],
#          [ 53,  70, 134],
#          ...,
#          [158, 164, 168],
#          [157, 163, 167],
#          [152, 158, 162]],
#
#         [[ 50,  63, 125],
#          [ 51,  64, 126],
#          [ 51,  68, 132],
#          ...,
#          [135, 141, 145],
#          [132, 138, 142],
#          [126, 132, 136]],
#
#         [[ 50,  63, 125],
#          [ 50,  63, 125],
#          [ 51,  68, 132],
#          ...,
#          [105, 111, 115],
#          [108, 114, 118],
#          [114, 120, 124]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 1.8248558044433594, 'inference': 8.897542953491211, 'postprocess': 1.6341209411621094},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[ 45,  45,  45],
#          [ 45,  45,  45],
#          [ 45,  45,  45],
#          ...,
#          [197, 185, 178],
#          [198, 186, 179],
#          [198, 186, 179]],
#
#         [[ 45,  45,  45],
#          [ 45,  45,  45],
#          [ 46,  46,  46],
#          ...,
#          [197, 185, 178],
#          [197, 185, 178],
#          [199, 187, 180]],
#
#         [[ 45,  45,  45],
#          [ 46,  46,  46],
#          [ 46,  46,  46],
#          ...,
#          [198, 186, 179],
#          [199, 187, 180],
#          [199, 187, 180]],
#
#         ...,
#
#         [[ 55,  63, 128],
#          [ 53,  61, 126],
#          [ 50,  56, 119],
#          ...,
#          [171, 177, 181],
#          [166, 172, 176],
#          [163, 169, 173]],
#
#         [[ 44,  52, 117],
#          [ 45,  53, 118],
#          [ 46,  52, 115],
#          ...,
#          [172, 178, 182],
#          [169, 175, 179],
#          [167, 173, 177]],
#
#         [[ 35,  43, 108],
#          [ 38,  46, 111],
#          [ 41,  47, 110],
#          ...,
#          [174, 180, 184],
#          [171, 177, 181],
#          [167, 173, 177]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.0055770874023438, 'inference': 9.86027717590332, 'postprocess': 1.7287731170654297},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[ 46,  46,  46],
#          [ 46,  46,  46],
#          [ 46,  46,  46],
#          ...,
#          [236, 225, 216],
#          [235, 224, 215],
#          [243, 232, 223]],
#
#         [[ 46,  46,  46],
#          [ 46,  46,  46],
#          [ 47,  47,  47],
#          ...,
#          [236, 225, 216],
#          [235, 224, 215],
#          [243, 232, 223]],
#
#         [[ 47,  47,  47],
#          [ 47,  47,  47],
#          [ 47,  47,  47],
#          ...,
#          [236, 225, 216],
#          [235, 224, 215],
#          [243, 232, 223]],
#
#         ...,
#
#         [[ 41,  62,  88],
#          [ 41,  62,  88],
#          [ 44,  65,  91],
#          ...,
#          [165, 171, 175],
#          [172, 178, 182],
#          [164, 170, 174]],
#
#         [[ 21,  42,  68],
#          [ 20,  41,  67],
#          [ 23,  44,  70],
#          ...,
#          [150, 156, 160],
#          [139, 145, 149],
#          [147, 153, 157]],
#
#         [[ 13,  34,  60],
#          [ 12,  33,  59],
#          [ 12,  33,  59],
#          ...,
#          [149, 155, 159],
#          [143, 149, 153],
#          [151, 157, 161]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 1.9106864929199219, 'inference': 8.896112442016602, 'postprocess': 1.7211437225341797},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[ 46,  46,  46],
#          [ 46,  46,  46],
#          [ 46,  46,  46],
#          ...,
#          [233, 224, 208],
#          [235, 225, 211],
#          [236, 226, 212]],
#
#         [[ 46,  46,  46],
#          [ 46,  46,  46],
#          [ 47,  47,  47],
#          ...,
#          [233, 224, 208],
#          [235, 225, 211],
#          [236, 226, 212]],
#
#         [[ 47,  47,  47],
#          [ 47,  47,  47],
#          [ 47,  47,  47],
#          ...,
#          [231, 224, 209],
#          [234, 226, 214],
#          [235, 227, 215]],
#
#         ...,
#
#         [[ 40,  58, 104],
#          [ 40,  58, 104],
#          [ 41,  59, 105],
#          ...,
#          [169, 175, 179],
#          [174, 180, 184],
#          [172, 178, 182]],
#
#         [[ 36,  54, 100],
#          [ 36,  54, 100],
#          [ 36,  54, 100],
#          ...,
#          [169, 175, 179],
#          [173, 179, 183],
#          [172, 178, 182]],
#
#         [[ 31,  49,  95],
#          [ 31,  49,  95],
#          [ 31,  49,  95],
#          ...,
#          [168, 174, 178],
#          [173, 179, 183],
#          [171, 177, 181]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 1.7514228820800781, 'inference': 10.77127456665039, 'postprocess': 1.718759536743164},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[ 46,  46,  46],
#          [ 46,  46,  46],
#          [ 46,  46,  46],
#          ...,
#          [188, 179, 163],
#          [185, 176, 160],
#          [185, 176, 160]],
#
#         [[ 46,  46,  46],
#          [ 46,  46,  46],
#          [ 47,  47,  47],
#          ...,
#          [190, 181, 165],
#          [187, 178, 162],
#          [186, 177, 161]],
#
#         [[ 47,  47,  47],
#          [ 47,  47,  47],
#          [ 47,  47,  47],
#          ...,
#          [190, 181, 165],
#          [187, 178, 162],
#          [186, 177, 161]],
#
#         ...,
#
#         [[ 55,  63, 128],
#          [ 54,  62, 127],
#          [ 53,  61, 126],
#          ...,
#          [147, 153, 157],
#          [154, 160, 164],
#          [154, 160, 164]],
#
#         [[ 39,  47, 112],
#          [ 40,  48, 113],
#          [ 41,  49, 114],
#          ...,
#          [168, 174, 178],
#          [175, 181, 185],
#          [175, 181, 185]],
#
#         [[ 30,  38, 103],
#          [ 32,  40, 105],
#          [ 35,  43, 108],
#          ...,
#          [179, 185, 189],
#          [186, 192, 196],
#          [186, 192, 196]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 1.8334388732910156, 'inference': 8.383989334106445, 'postprocess': 1.5664100646972656},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[ 47,  47,  47],
#          [ 47,  47,  47],
#          [ 48,  48,  48],
#          ...,
#          [188, 181, 160],
#          [188, 181, 160],
#          [188, 181, 160]],
#
#         [[ 48,  48,  48],
#          [ 48,  48,  48],
#          [ 48,  48,  48],
#          ...,
#          [187, 180, 159],
#          [188, 181, 160],
#          [188, 181, 160]],
#
#         [[ 48,  48,  48],
#          [ 48,  48,  48],
#          [ 48,  48,  48],
#          ...,
#          [187, 180, 159],
#          [187, 180, 159],
#          [188, 181, 160]],
#
#         ...,
#
#         [[ 30,  42,  95],
#          [ 30,  42,  95],
#          [ 30,  42,  95],
#          ...,
#          [151, 157, 161],
#          [174, 180, 184],
#          [186, 192, 196]],
#
#         [[ 30,  42,  95],
#          [ 30,  42,  95],
#          [ 30,  42,  95],
#          ...,
#          [161, 167, 171],
#          [185, 191, 195],
#          [196, 202, 206]],
#
#         [[ 30,  42,  95],
#          [ 30,  42,  95],
#          [ 30,  42,  95],
#          ...,
#          [161, 167, 171],
#          [185, 191, 195],
#          [196, 202, 206]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 1.844644546508789, 'inference': 9.539365768432617, 'postprocess': 1.9218921661376953},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[ 52,  52,  52],
#          [ 52,  52,  52],
#          [ 52,  52,  52],
#          ...,
#          [192, 185, 164],
#          [194, 187, 166],
#          [197, 190, 169]],
#
#         [[ 52,  52,  52],
#          [ 52,  52,  52],
#          [ 53,  53,  53],
#          ...,
#          [192, 185, 164],
#          [194, 187, 166],
#          [197, 190, 169]],
#
#         [[ 53,  53,  53],
#          [ 53,  53,  53],
#          [ 53,  53,  53],
#          ...,
#          [192, 185, 164],
#          [194, 187, 166],
#          [197, 190, 169]],
#
#         ...,
#
#         [[ 53,  65, 123],
#          [ 53,  65, 123],
#          [ 47,  64, 128],
#          ...,
#          [167, 173, 177],
#          [163, 169, 173],
#          [163, 169, 173]],
#
#         [[ 52,  64, 122],
#          [ 52,  64, 122],
#          [ 46,  63, 127],
#          ...,
#          [172, 178, 182],
#          [167, 173, 177],
#          [167, 173, 177]],
#
#         [[ 52,  64, 122],
#          [ 52,  64, 122],
#          [ 46,  63, 127],
#          ...,
#          [164, 170, 174],
#          [159, 165, 169],
#          [159, 165, 169]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 1.917123794555664, 'inference': 8.837699890136719, 'postprocess': 1.6913414001464844},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[ 54,  54,  54],
#          [ 54,  54,  54],
#          [ 55,  55,  55],
#          ...,
#          [221, 214, 193],
#          [225, 218, 197],
#          [223, 216, 195]],
#
#         [[ 55,  55,  55],
#          [ 55,  55,  55],
#          [ 57,  57,  57],
#          ...,
#          [223, 216, 195],
#          [227, 220, 199],
#          [223, 216, 195]],
#
#         [[ 55,  55,  55],
#          [ 55,  55,  55],
#          [ 57,  57,  57],
#          ...,
#          [226, 218, 199],
#          [230, 222, 203],
#          [228, 220, 201]],
#
#         ...,
#
#         [[ 57,  61, 104],
#          [ 68,  72, 115],
#          [ 88,  92, 135],
#          ...,
#          [157, 163, 167],
#          [163, 169, 173],
#          [163, 169, 173]],
#
#         [[ 31,  39,  82],
#          [ 41,  49,  92],
#          [ 62,  70, 113],
#          ...,
#          [163, 169, 173],
#          [168, 174, 178],
#          [168, 174, 178]],
#
#         [[ 19,  27,  70],
#          [ 30,  38,  81],
#          [ 51,  59, 102],
#          ...,
#          [163, 169, 173],
#          [168, 174, 178],
#          [168, 174, 178]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 1.7108917236328125, 'inference': 9.022951126098633, 'postprocess': 1.554727554321289},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[ 55,  55,  55],
#          [ 55,  55,  55],
#          [ 57,  57,  57],
#          ...,
#          [207, 197, 183],
#          [209, 200, 184],
#          [209, 200, 184]],
#
#         [[ 57,  57,  57],
#          [ 57,  57,  57],
#          [ 57,  57,  57],
#          ...,
#          [168, 158, 144],
#          [177, 168, 152],
#          [176, 167, 151]],
#
#         [[ 57,  57,  57],
#          [ 57,  57,  57],
#          [ 57,  57,  57],
#          ...,
#          [161, 151, 137],
#          [177, 167, 153],
#          [183, 173, 159]],
#
#         ...,
#
#         [[111, 108, 107],
#          [111, 108, 107],
#          [111, 108, 107],
#          ...,
#          [131, 137, 141],
#          [131, 137, 141],
#          [125, 131, 135]],
#
#         [[111, 108, 107],
#          [111, 108, 107],
#          [111, 108, 107],
#          ...,
#          [152, 158, 162],
#          [152, 158, 162],
#          [146, 152, 156]],
#
#         [[111, 108, 107],
#          [111, 108, 107],
#          [111, 108, 107],
#          ...,
#          [166, 172, 176],
#          [163, 169, 173],
#          [157, 163, 167]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.6350021362304688, 'inference': 9.0179443359375, 'postprocess': 1.6672611236572266},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[ 57,  57,  57],
#          [ 57,  57,  57],
#          [ 58,  58,  58],
#          ...,
#          [213, 199, 184],
#          [213, 199, 184],
#          [213, 199, 184]],
#
#         [[ 58,  58,  58],
#          [ 58,  58,  58],
#          [ 58,  58,  58],
#          ...,
#          [213, 199, 184],
#          [213, 199, 184],
#          [213, 199, 184]],
#
#         [[ 58,  58,  58],
#          [ 58,  58,  58],
#          [ 59,  59,  59],
#          ...,
#          [213, 199, 184],
#          [213, 199, 184],
#          [213, 199, 184]],
#
#         ...,
#
#         [[111, 108, 109],
#          [111, 108, 109],
#          [111, 108, 109],
#          ...,
#          [139, 145, 149],
#          [132, 138, 142],
#          [130, 136, 140]],
#
#         [[109, 108, 110],
#          [109, 108, 110],
#          [109, 108, 110],
#          ...,
#          [143, 149, 153],
#          [136, 142, 146],
#          [133, 139, 143]],
#
#         [[109, 108, 110],
#          [109, 108, 110],
#          [109, 108, 110],
#          ...,
#          [143, 149, 153],
#          [136, 142, 146],
#          [133, 139, 143]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 1.8537044525146484, 'inference': 8.794784545898438, 'postprocess': 1.7364025115966797},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[ 58,  58,  58],
#          [ 58,  58,  58],
#          [ 59,  59,  59],
#          ...,
#          [217, 204, 186],
#          [218, 205, 187],
#          [217, 204, 186]],
#
#         [[ 58,  58,  58],
#          [ 58,  58,  58],
#          [ 59,  59,  59],
#          ...,
#          [218, 205, 187],
#          [218, 205, 187],
#          [218, 205, 187]],
#
#         [[ 60,  60,  60],
#          [ 60,  60,  60],
#          [ 60,  60,  60],
#          ...,
#          [219, 206, 188],
#          [218, 205, 187],
#          [218, 205, 187]],
#
#         ...,
#
#         [[ 52,  72, 113],
#          [ 51,  71, 112],
#          [ 51,  71, 112],
#          ...,
#          [156, 162, 166],
#          [155, 163, 167],
#          [154, 162, 166]],
#
#         [[ 38,  61, 114],
#          [ 37,  60, 113],
#          [ 39,  60, 112],
#          ...,
#          [157, 163, 167],
#          [159, 167, 171],
#          [158, 166, 170]],
#
#         [[ 42,  65, 118],
#          [ 41,  64, 117],
#          [ 44,  65, 117],
#          ...,
#          [157, 163, 167],
#          [159, 167, 171],
#          [158, 166, 170]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 1.7600059509277344, 'inference': 9.984493255615234, 'postprocess': 1.7478466033935547},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[ 59,  59,  59],
#          [ 59,  59,  59],
#          [ 60,  60,  60],
#          ...,
#          [213, 200, 182],
#          [216, 203, 185],
#          [217, 204, 186]],
#
#         [[ 59,  59,  59],
#          [ 59,  59,  59],
#          [ 60,  60,  60],
#          ...,
#          [220, 207, 189],
#          [218, 205, 187],
#          [218, 205, 187]],
#
#         [[ 61,  61,  61],
#          [ 61,  61,  61],
#          [ 62,  62,  62],
#          ...,
#          [224, 211, 193],
#          [220, 207, 189],
#          [218, 205, 187]],
#
#         ...,
#
#         [[ 44,  53, 115],
#          [ 44,  53, 115],
#          [ 46,  55, 117],
#          ...,
#          [115, 121, 125],
#          [124, 130, 134],
#          [130, 136, 140]],
#
#         [[ 40,  48, 113],
#          [ 40,  48, 113],
#          [ 40,  48, 113],
#          ...,
#          [110, 116, 120],
#          [119, 125, 129],
#          [125, 131, 135]],
#
#         [[ 24,  32,  97],
#          [ 24,  32,  97],
#          [ 25,  33,  98],
#          ...,
#          [110, 116, 120],
#          [119, 125, 129],
#          [125, 131, 135]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 2.1016597747802734, 'inference': 9.756088256835938, 'postprocess': 1.6613006591796875},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[ 59,  59,  59],
#          [ 59,  59,  59],
#          [ 60,  60,  60],
#          ...,
#          [224, 211, 193],
#          [222, 209, 191],
#          [219, 206, 188]],
#
#         [[ 59,  59,  59],
#          [ 59,  59,  59],
#          [ 60,  60,  60],
#          ...,
#          [225, 212, 194],
#          [223, 210, 192],
#          [220, 207, 189]],
#
#         [[ 61,  61,  61],
#          [ 61,  61,  61],
#          [ 62,  62,  62],
#          ...,
#          [222, 209, 191],
#          [218, 205, 187],
#          [215, 202, 184]],
#
#         ...,
#
#         [[ 30,  39, 101],
#          [ 30,  39, 101],
#          [ 31,  40, 102],
#          ...,
#          [139, 149, 153],
#          [133, 141, 145],
#          [141, 149, 153]],
#
#         [[ 16,  24,  89],
#          [ 16,  24,  89],
#          [ 16,  24,  89],
#          ...,
#          [131, 141, 145],
#          [133, 141, 145],
#          [142, 150, 154]],
#
#         [[ 10,  18,  83],
#          [ 10,  18,  83],
#          [ 12,  20,  85],
#          ...,
#          [104, 114, 118],
#          [131, 139, 143],
#          [142, 150, 154]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 1.7540454864501953, 'inference': 8.139848709106445, 'postprocess': 1.542806625366211},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[ 59,  59,  59],
#          [ 59,  59,  59],
#          [ 60,  60,  60],
#          ...,
#          [224, 211, 193],
#          [225, 212, 194],
#          [227, 214, 196]],
#
#         [[ 59,  59,  59],
#          [ 59,  59,  59],
#          [ 60,  60,  60],
#          ...,
#          [224, 211, 193],
#          [223, 210, 192],
#          [222, 209, 191]],
#
#         [[ 61,  61,  61],
#          [ 61,  61,  61],
#          [ 62,  62,  62],
#          ...,
#          [215, 202, 184],
#          [213, 200, 182],
#          [211, 198, 180]],
#
#         ...,
#
#         [[ 59,  63, 106],
#          [ 59,  63, 106],
#          [ 62,  66, 109],
#          ...,
#          [173, 188, 191],
#          [175, 190, 193],
#          [174, 189, 192]],
#
#         [[ 46,  55, 104],
#          [ 46,  55, 104],
#          [ 49,  57, 108],
#          ...,
#          [163, 176, 179],
#          [155, 170, 173],
#          [145, 160, 163]],
#
#         [[ 42,  51, 100],
#          [ 42,  51, 100],
#          [ 44,  52, 103],
#          ...,
#          [158, 171, 174],
#          [138, 153, 156],
#          [122, 137, 140]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 1.8761157989501953, 'inference': 9.837627410888672, 'postprocess': 1.561880111694336},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[ 59,  59,  59],
#          [ 59,  59,  59],
#          [ 60,  60,  60],
#          ...,
#          [222, 207, 194],
#          [222, 207, 194],
#          [222, 207, 194]],
#
#         [[ 59,  59,  59],
#          [ 59,  59,  59],
#          [ 60,  60,  60],
#          ...,
#          [222, 207, 194],
#          [222, 207, 194],
#          [222, 207, 194]],
#
#         [[ 61,  61,  61],
#          [ 61,  61,  61],
#          [ 62,  62,  62],
#          ...,
#          [213, 198, 185],
#          [213, 198, 185],
#          [213, 198, 185]],
#
#         ...,
#
#         [[110, 107, 106],
#          [110, 107, 106],
#          [110, 107, 106],
#          ...,
#          [144, 153, 193],
#          [144, 153, 193],
#          [144, 153, 193]],
#
#         [[110, 107, 106],
#          [110, 107, 106],
#          [110, 107, 106],
#          ...,
#          [143, 153, 189],
#          [142, 152, 188],
#          [142, 152, 188]],
#
#         [[110, 107, 106],
#          [110, 107, 106],
#          [110, 107, 106],
#          ...,
#          [143, 153, 189],
#          [142, 152, 188],
#          [142, 152, 188]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 1.8329620361328125, 'inference': 9.865283966064453, 'postprocess': 1.5077590942382812},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[ 59,  59,  59],
#          [ 59,  59,  59],
#          [ 60,  60,  60],
#          ...,
#          [185, 180, 160],
#          [185, 180, 160],
#          [185, 180, 160]],
#
#         [[ 59,  59,  59],
#          [ 59,  59,  59],
#          [ 60,  60,  60],
#          ...,
#          [185, 180, 160],
#          [185, 180, 160],
#          [185, 180, 160]],
#
#         [[ 61,  61,  61],
#          [ 61,  61,  61],
#          [ 62,  62,  62],
#          ...,
#          [185, 180, 160],
#          [185, 180, 160],
#          [185, 180, 160]],
#
#         ...,
#
#         [[114, 111, 110],
#          [114, 111, 110],
#          [114, 111, 110],
#          ...,
#          [174, 180, 184],
#          [183, 189, 193],
#          [188, 194, 198]],
#
#         [[114, 111, 110],
# ...
#          [121, 109, 102],
#          [121, 109, 102]],
#
#         ...,
#
#         [[188, 197, 198],
#          [195, 204, 205],
#          [207, 216, 217],
#          ...,
#          [152,  63,  30],
#          [152,  63,  30],
#          [152,  63,  30]],
#
#         [[186, 195, 196],
#          [194, 203, 204],
#          [209, 218, 219],
#          ...,
#          [152,  63,  30],
#          [152,  63,  30],
#          [152,  63,  30]],
#
#         [[186, 195, 196],
#          [194, 203, 204],
#          [209, 218, 219],
#          ...,
#          [152,  63,  30],
#          [152,  63,  30],
#          [152,  63,  30]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 1.9850730895996094, 'inference': 9.202957153320312, 'postprocess': 1.569986343383789},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[132, 132, 132],
#          [132, 132, 132],
#          [131, 131, 131],
#          ...,
#          [138, 127, 116],
#          [140, 129, 118],
#          [140, 129, 118]],
#
#         [[132, 132, 132],
#          [132, 132, 132],
#          [131, 131, 131],
#          ...,
#          [141, 130, 119],
#          [142, 131, 120],
#          [141, 130, 119]],
#
#         [[132, 132, 132],
#          [132, 132, 132],
#          [131, 131, 131],
#          ...,
#          [137, 128, 112],
#          [137, 128, 112],
#          [138, 129, 113]],
#
#         ...,
#
#         [[212, 221, 222],
#          [212, 221, 222],
#          [213, 222, 223],
#          ...,
#          [152,  63,  30],
#          [152,  63,  30],
#          [152,  63,  30]],
#
#         [[212, 221, 222],
#          [212, 221, 222],
#          [211, 220, 221],
#          ...,
#          [152,  63,  30],
#          [152,  63,  30],
#          [152,  63,  30]],
#
#         [[212, 221, 222],
#          [212, 221, 222],
#          [208, 217, 218],
#          ...,
#          [152,  63,  30],
#          [152,  63,  30],
#          [152,  63,  30]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 1.9116401672363281, 'inference': 10.422468185424805, 'postprocess': 1.6770362854003906},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[130, 130, 130],
#          [130, 130, 130],
#          [129, 129, 129],
#          ...,
#          [138, 129, 113],
#          [138, 129, 113],
#          [138, 129, 113]],
#
#         [[130, 130, 130],
#          [130, 130, 130],
#          [129, 129, 129],
#          ...,
#          [140, 131, 115],
#          [140, 131, 115],
#          [140, 131, 115]],
#
#         [[130, 130, 130],
#          [130, 130, 130],
#          [129, 129, 129],
#          ...,
#          [142, 135, 114],
#          [142, 135, 114],
#          [142, 135, 114]],
#
#         ...,
#
#         [[214, 223, 224],
#          [215, 224, 225],
#          [218, 227, 228],
#          ...,
#          [152,  63,  30],
#          [152,  63,  30],
#          [152,  63,  30]],
#
#         [[215, 224, 225],
#          [216, 225, 226],
#          [220, 229, 230],
#          ...,
#          [152,  63,  30],
#          [152,  63,  30],
#          [152,  63,  30]],
#
#         [[213, 222, 223],
#          [213, 222, 223],
#          [219, 228, 229],
#          ...,
#          [152,  63,  30],
#          [152,  63,  30],
#          [152,  63,  30]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 1.8618106842041016, 'inference': 8.380413055419922, 'postprocess': 1.583099365234375},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[129, 129, 129],
#          [129, 129, 129],
#          [128, 128, 128],
#          ...,
#          [144, 137, 116],
#          [144, 137, 116],
#          [144, 137, 116]],
#
#         [[129, 129, 129],
#          [129, 129, 129],
#          [128, 128, 128],
#          ...,
#          [144, 137, 116],
#          [144, 137, 116],
#          [144, 137, 116]],
#
#         [[129, 129, 129],
#          [129, 129, 129],
#          [128, 128, 128],
#          ...,
#          [148, 141, 120],
#          [148, 141, 120],
#          [148, 141, 120]],
#
#         ...,
#
#         [[211, 220, 221],
#          [211, 220, 221],
#          [211, 220, 221],
#          ...,
#          [152,  63,  30],
#          [152,  63,  30],
#          [152,  63,  30]],
#
#         [[211, 220, 221],
#          [211, 220, 221],
#          [211, 220, 221],
#          ...,
#          [152,  63,  30],
#          [152,  63,  30],
#          [152,  63,  30]],
#
#         [[211, 220, 221],
#          [211, 220, 221],
#          [211, 220, 221],
#          ...,
#          [152,  63,  30],
#          [152,  63,  30],
#          [152,  63,  30]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 1.7559528350830078, 'inference': 11.088132858276367, 'postprocess': 1.6150474548339844},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[125, 125, 125],
#          [125, 125, 125],
#          [123, 123, 123],
#          ...,
#          [144, 137, 116],
#          [144, 137, 116],
#          [144, 137, 116]],
#
#         [[125, 125, 125],
#          [125, 125, 125],
#          [123, 123, 123],
#          ...,
#          [148, 141, 120],
#          [148, 141, 120],
#          [148, 141, 120]],
#
#         [[126, 126, 126],
#          [126, 126, 126],
#          [124, 124, 124],
#          ...,
#          [149, 142, 121],
#          [149, 142, 121],
#          [149, 142, 121]],
#
#         ...,
#
#         [[211, 220, 221],
#          [211, 220, 221],
#          [209, 218, 219],
#          ...,
#          [152,  63,  30],
#          [152,  63,  30],
#          [152,  63,  30]],
#
#         [[211, 220, 221],
#          [211, 220, 221],
#          [209, 218, 219],
#          ...,
#          [152,  63,  30],
#          [152,  63,  30],
#          [152,  63,  30]],
#
#         [[211, 220, 221],
#          [211, 220, 221],
#          [209, 218, 219],
#          ...,
#          [152,  63,  30],
#          [152,  63,  30],
#          [152,  63,  30]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 1.8742084503173828, 'inference': 8.769512176513672, 'postprocess': 1.7015933990478516},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[121, 121, 121],
#          [121, 121, 121],
#          [119, 119, 119],
#          ...,
#          [148, 141, 120],
#          [148, 141, 120],
#          [148, 141, 120]],
#
#         [[121, 121, 121],
#          [121, 121, 121],
#          [119, 119, 119],
#          ...,
#          [148, 141, 120],
#          [148, 141, 120],
#          [148, 141, 120]],
#
#         [[122, 122, 122],
#          [122, 122, 122],
#          [119, 119, 119],
#          ...,
#          [148, 141, 120],
#          [148, 141, 120],
#          [148, 141, 120]],
#
#         ...,
#
#         [[204, 213, 214],
#          [204, 213, 214],
#          [204, 213, 214],
#          ...,
#          [152,  63,  30],
#          [152,  63,  30],
#          [152,  63,  30]],
#
#         [[207, 216, 217],
#          [207, 216, 217],
#          [208, 217, 218],
#          ...,
#          [152,  63,  30],
#          [152,  63,  30],
#          [152,  63,  30]],
#
#         [[209, 218, 219],
#          [209, 218, 219],
#          [211, 220, 221],
#          ...,
#          [152,  63,  30],
#          [152,  63,  30],
#          [152,  63,  30]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 1.781463623046875, 'inference': 9.446382522583008, 'postprocess': 1.6636848449707031},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[125, 125, 125],
#          [125, 125, 125],
#          [123, 123, 123],
#          ...,
#          [148, 141, 120],
#          [148, 141, 120],
#          [148, 141, 120]],
#
#         [[125, 125, 125],
#          [125, 125, 125],
#          [123, 123, 123],
#          ...,
#          [148, 141, 120],
#          [148, 141, 120],
#          [148, 141, 120]],
#
#         [[126, 126, 126],
#          [126, 126, 126],
#          [124, 124, 124],
#          ...,
#          [148, 141, 120],
#          [148, 141, 120],
#          [148, 141, 120]],
#
#         ...,
#
#         [[211, 220, 221],
#          [211, 220, 221],
#          [212, 220, 224],
#          ...,
#          [150,  61,  28],
#          [150,  61,  28],
#          [150,  61,  28]],
#
#         [[211, 220, 221],
#          [211, 220, 221],
#          [213, 221, 225],
#          ...,
#          [150,  61,  28],
#          [150,  61,  28],
#          [150,  61,  28]],
#
#         [[211, 220, 221],
#          [212, 221, 222],
#          [214, 222, 226],
#          ...,
#          [150,  61,  28],
#          [150,  61,  28],
#          [150,  61,  28]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 3.081798553466797, 'inference': 10.638713836669922, 'postprocess': 1.54876708984375},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[111, 111, 111],
#          [111, 111, 111],
#          [111, 111, 111],
#          ...,
#          [148, 141, 120],
#          [148, 141, 120],
#          [148, 141, 120]],
#
#         [[111, 111, 111],
#          [111, 111, 111],
#          [111, 111, 111],
#          ...,
#          [149, 142, 121],
#          [149, 142, 121],
#          [149, 142, 121]],
#
#         [[111, 111, 111],
#          [111, 111, 111],
#          [111, 111, 111],
#          ...,
#          [151, 144, 121],
#          [151, 144, 121],
#          [151, 144, 121]],
#
#         ...,
#
#         [[212, 218, 227],
#          [206, 212, 221],
#          [184, 186, 207],
#          ...,
#          [150,  61,  28],
#          [150,  61,  28],
#          [150,  61,  28]],
#
#         [[161, 164, 182],
#          [154, 157, 175],
#          [136, 132, 172],
#          ...,
#          [150,  61,  28],
#          [150,  61,  28],
#          [150,  61,  28]],
#
#         [[ 89,  92, 110],
#          [ 92,  95, 113],
#          [ 95,  91, 131],
#          ...,
#          [150,  61,  28],
#          [150,  61,  28],
#          [150,  61,  28]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 1.7421245574951172, 'inference': 9.329080581665039, 'postprocess': 1.6696453094482422},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[119, 119, 119],
#          [122, 122, 122],
#          [123, 122, 124],
#          ...,
#          [151, 144, 121],
#          [151, 144, 121],
#          [151, 144, 121]],
#
#         [[119, 119, 119],
#          [122, 122, 122],
#          [124, 123, 125],
#          ...,
#          [154, 147, 124],
#          [154, 147, 124],
#          [154, 147, 124]],
#
#         [[119, 119, 119],
#          [122, 122, 122],
#          [124, 123, 125],
#          ...,
#          [161, 154, 131],
#          [161, 154, 131],
#          [161, 154, 131]],
#
#         ...,
#
#         [[147, 147, 175],
#          [117, 117, 145],
#          [103, 101, 134],
#          ...,
#          [149,  60,  27],
#          [149,  60,  27],
#          [150,  61,  28]],
#
#         [[107, 102, 144],
#          [101,  96, 138],
#          [106,  98, 150],
#          ...,
#          [149,  60,  27],
#          [149,  60,  27],
#          [150,  61,  28]],
#
#         [[ 94,  89, 131],
#          [ 99,  94, 136],
#          [105,  97, 149],
#          ...,
#          [149,  60,  27],
#          [149,  60,  27],
#          [150,  61,  28]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 1.9016265869140625, 'inference': 8.179903030395508, 'postprocess': 1.7137527465820312},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[137, 136, 138],
#          [138, 137, 139],
#          [143, 142, 144],
#          ...,
#          [163, 156, 133],
#          [163, 156, 133],
#          [163, 156, 133]],
#
#         [[137, 136, 138],
#          [138, 137, 139],
#          [143, 142, 144],
#          ...,
#          [163, 156, 133],
#          [163, 156, 133],
#          [163, 156, 133]],
#
#         [[137, 136, 138],
#          [138, 137, 139],
#          [143, 142, 144],
#          ...,
#          [170, 163, 140],
#          [170, 163, 140],
#          [170, 163, 140]],
#
#         ...,
#
#         [[ 89,  80, 134],
#          [ 91,  82, 136],
#          [ 92,  84, 136],
#          ...,
#          [131, 149, 163],
#          [131, 149, 163],
#          [131, 149, 163]],
#
#         [[ 81,  69, 131],
#          [ 73,  61, 123],
#          [ 63,  52, 111],
#          ...,
#          [131, 149, 163],
#          [131, 149, 163],
#          [131, 149, 163]],
#
#         [[ 80,  68, 130],
#          [ 69,  57, 119],
#          [ 56,  45, 104],
#          ...,
#          [129, 147, 161],
#          [129, 147, 161],
#          [129, 147, 161]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 1.928091049194336, 'inference': 8.406877517700195, 'postprocess': 1.6880035400390625},
#  ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'Violence', 1: 'Weapon', 2: 'Fire', 3: 'Smoke'}
#  orig_img: array([[[150, 149, 151],
#          [152, 151, 153],
#          [159, 158, 160],
#          ...,
#          [168, 164, 142],
#          [180, 176, 154],
#          [185, 181, 159]],
#
#         [[150, 149, 151],
#          [152, 151, 153],
#          [159, 158, 160],
#          ...,
#          [181, 177, 155],
#          [192, 188, 166],
#          [198, 194, 172]],
#
#         [[150, 149, 151],
#          [152, 151, 153],
#          [159, 158, 160],
#          ...,
#          [179, 172, 151],
#          [191, 184, 163],
#          [197, 190, 169]],
#
#         ...,
#
#         [[ 89,  81, 133],
#          [ 95,  87, 139],
#          [100,  92, 144],
#          ...,
#          [100, 119, 128],
#          [ 98, 117, 126],
#          [ 98, 117, 126]],
#
#         [[ 84,  72, 134],
#          [ 84,  72, 134],
#          [ 78,  66, 128],
#          ...,
#          [100, 119, 128],
#          [ 98, 117, 126],
#          [ 98, 117, 126]],
#
#         [[ 78,  66, 128],
#          [ 78,  66, 128],
#          [ 60,  48, 110],
#          ...,
#          [100, 119, 128],
#          [ 98, 117, 126],
#          [ 98, 117, 126]]], dtype=uint8)
#  orig_shape: (720, 1280)
#  path: '/content/fire_smoke.mp4'
#  probs: None
#  save_dir: 'runs/detect/predict'
#  speed: {'preprocess': 1.9254684448242188, 'inference': 8.408308029174805, 'postprocess': 1.5323162078857422}]

# %%
img = fswv[0].plot()
# img = plt.imshow(img,cmap='gray')
img = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()
